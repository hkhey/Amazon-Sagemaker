# %%
import pandas as pd

dataset = pd.read_csv('housing.csv')

# %%
print(dataset.shape)
dataset[:5]
# Out:
# (506, 13)
#       crim    zn  indus  chas    nox    age    rm     dis  rad    tax  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    ptratio  lstat  medv
# 0     15.3   4.98  24.0
# 1     17.8   9.14  21.6
# 2     17.8   4.03  34.7
# 3     18.7   2.94  33.4
# 4     18.7   5.33  36.2

# %%
# Move 'medv' column to front
dataset = pd.concat([dataset['medv'], dataset.drop(['medv'], axis=1)], axis=1)

# %%
from sklearn.model_selection import train_test_split
training_dataset, validation_dataset = train_test_split(dataset, test_size=0.1)

print(training_dataset.shape)
print(validation_dataset.shape)
# Out:
# (455, 13)
# (51, 13)

# %%
training_dataset.to_csv('training_dataset.csv', index=False, header=False)
validation_dataset.to_csv('validation_dataset.csv', index=False, header=False)

# %%
import sagemaker

print(sagemaker.__version__)

sess = sagemaker.Session()
bucket = sess.default_bucket()

prefix = 'boston-housing'
training_data_path = sess.upload_data(path='training_dataset.csv', key_prefix=prefix + '/input/training')
validation_data_path = sess.upload_data(path='validation_dataset.csv', key_prefix=prefix + '/input/validation')

print(training_data_path)
print(validation_data_path)
# Out:
# 2.86.2
# s3://sagemaker-us-east-1-878904878863/boston-housing/input/training/training_dataset.csv
# s3://sagemaker-us-east-1-878904878863/boston-housing/input/validation/validation_dataset.csv

# %%
import boto3
from sagemaker import image_uris

region = boto3.Session().region_name    
container = image_uris.retrieve('linear-learner', region)

print(container)

from sagemaker.estimator import Estimator

role = sagemaker.get_execution_role() 

ll_estimator = Estimator(container,
    role=role, 
    instance_count=1,
    instance_type='ml.m5.large',
    output_path='s3://{}/{}/output'.format(bucket, prefix)
)

ll_estimator.set_hyperparameters(predictor_type='regressor', mini_batch_size=32)
# Out:
# 382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:1

# %%
training_data_channel   = sagemaker.TrainingInput(s3_data=training_data_path, content_type='text/csv')
validation_data_channel = sagemaker.TrainingInput(s3_data=validation_data_path, content_type='text/csv')

ll_data = {'train': training_data_channel, 'validation': validation_data_channel}

# %%
ll_estimator.fit(ll_data)
# Out:
# 2022-06-25 17:44:05 Starting - Starting the training job...
# 2022-06-25 17:44:29 Starting - Preparing the instances for trainingProfilerReport-1656179045: InProgress
# ......
# 2022-06-25 17:45:30 Downloading - Downloading input data......
# 2022-06-25 17:46:30 Training - Downloading the training image......
# 2022-06-25 17:47:30 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [06/25/2022 17:47:30 INFO 140021956077376] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [06/25/2022 17:47:30 INFO 140021956077376] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'mini_batch_size': '32', 'predictor_type': 'regressor'}
# [06/25/2022 17:47:30 INFO 140021956077376] Final configuration: {'mini_batch_size': '32', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [06/25/2022 17:47:30 WARNING 140021956077376] Loggers have already been setup.
# Process 1 is a worker.
# [06/25/2022 17:47:30 INFO 140021956077376] Using default worker.
# [06/25/2022 17:47:30 INFO 140021956077376] Checkpoint loading and saving are disabled.
# [06/25/2022 17:47:30 INFO 140021956077376] Create Store: local
# [06/25/2022 17:47:31 INFO 140021956077376] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f58f1446350>
# [06/25/2022 17:47:31 INFO 140021956077376] Scaling model computed with parameters:
#  {'stdev_label':
# [9.1888275]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [8.9009790e+00 2.2655537e+01 6.8392363e+00 2.5378790e-01 1.1652138e-01
#  6.9635582e-01 2.8089298e+01 2.0858209e+00 8.6609335e+00 1.6779933e+02
#  2.1723244e+00 7.1626487e+00]
# <NDArray 12 @cpu(0)>, 'mean_label':
# [22.52701]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [3.6730890e+00 1.0861608e+01 1.1148840e+01 6.9196433e-02 5.5628073e-01
#  6.2773738e+00 6.8739952e+01 3.7567005e+00 9.5401793e+00 4.0900668e+02
#  1.8435715e+01 1.2669129e+01]
# <NDArray 12 @cpu(0)>}
# [06/25/2022 17:47:31 INFO 140021956077376] nvidia-smi: took 0.033 seconds to run.
# [06/25/2022 17:47:31 INFO 140021956077376] nvidia-smi identified 0 GPUs.
# [06/25/2022 17:47:31 INFO 140021956077376] Number of GPUs being used: 0
# #metrics {"StartTime": 1656179251.3195677, "EndTime": 1656179251.3196194, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 487.0, "count": 1, "min": 487, "max": 487}, "Total Batches Seen": {"sum": 16.0, "count": 1, "min": 16, "max": 16}, "Max Records Seen Between Resets": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Max Batches Seen Between Resets": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# #metrics {"StartTime": 1656179251.7833495, "EndTime": 1656179251.7834268, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.7465185203722545, "count": 1, "min": 0.7465185203722545, "max": 0.7465185203722545}}}
# #metrics {"StartTime": 1656179251.7835097, "EndTime": 1656179251.7835221, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.8377349951437542, "count": 1, "min": 0.8377349951437542, "max": 0.8377349951437542}}}
# #metrics {"StartTime": 1656179251.7835588, "EndTime": 1656179251.7835681, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.8970558877502169, "count": 1, "min": 0.8970558877502169, "max": 0.8970558877502169}}}
# #metrics {"StartTime": 1656179251.7836225, "EndTime": 1656179251.7836323, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.8913957221167428, "count": 1, "min": 0.8913957221167428, "max": 0.8913957221167428}}}
# #metrics {"StartTime": 1656179251.7836852, "EndTime": 1656179251.7836947, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.8774145479713168, "count": 1, "min": 0.8774145479713168, "max": 0.8774145479713168}}}
# #metrics {"StartTime": 1656179251.783728, "EndTime": 1656179251.7838306, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 1.051545881799289, "count": 1, "min": 1.051545881799289, "max": 1.051545881799289}}}
# #metrics {"StartTime": 1656179251.7838945, "EndTime": 1656179251.7839072, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.8151056085314069, "count": 1, "min": 0.8151056085314069, "max": 0.8151056085314069}}}
# #metrics {"StartTime": 1656179251.7839468, "EndTime": 1656179251.7840488, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.8727829945938927, "count": 1, "min": 0.8727829945938927, "max": 0.8727829945938927}}}
# #metrics {"StartTime": 1656179251.7840989, "EndTime": 1656179251.78417, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.8057771474123001, "count": 1, "min": 0.8057771474123001, "max": 0.8057771474123001}}}
# #metrics {"StartTime": 1656179251.7842708, "EndTime": 1656179251.7842863, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.6299981496163777, "count": 1, "min": 0.6299981496163777, "max": 0.6299981496163777}}}
# #metrics {"StartTime": 1656179251.7843404, "EndTime": 1656179251.7843525, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.9886845158679145, "count": 1, "min": 0.9886845158679145, "max": 0.9886845158679145}}}
# #metrics {"StartTime": 1656179251.784453, "EndTime": 1656179251.7844663, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.8809500549520765, "count": 1, "min": 0.8809500549520765, "max": 0.8809500549520765}}}
# #metrics {"StartTime": 1656179251.7846224, "EndTime": 1656179251.7846386, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.9856409217630114, "count": 1, "min": 0.9856409217630114, "max": 0.9856409217630114}}}
# #metrics {"StartTime": 1656179251.7847488, "EndTime": 1656179251.7847638, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.8188447164637702, "count": 1, "min": 0.8188447164637702, "max": 0.8188447164637702}}}
# #metrics {"StartTime": 1656179251.7848177, "EndTime": 1656179251.7848291, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 23.430512671377144, "count": 1, "min": 23.430512671377144, "max": 23.430512671377144}}}
# #metrics {"StartTime": 1656179252.4454942, "EndTime": 1656179252.445515, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 17.294642429725798, "count": 1, "min": 17.294642429725798, "max": 17.294642429725798}}}
# #metrics {"StartTime": 1656179252.4458168, "EndTime": 1656179252.4458547, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 18.94819371840533, "count": 1, "min": 18.94819371840533, "max": 18.94819371840533}}}
# #metrics {"StartTime": 1656179252.4461544, "EndTime": 1656179252.4461904, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 20.950757793351716, "count": 1, "min": 20.950757793351716, "max": 20.950757793351716}}}
# #metrics {"StartTime": 1656179252.4464726, "EndTime": 1656179252.4465296, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 16.378703397863053, "count": 1, "min": 16.378703397863053, "max": 16.378703397863053}}}
# #metrics {"StartTime": 1656179252.44683, "EndTime": 1656179252.4468696, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 20.4757905847886, "count": 1, "min": 20.4757905847886, "max": 20.4757905847886}}}
# #metrics {"StartTime": 1656179252.4471612, "EndTime": 1656179252.4471803, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 22.278893564261644, "count": 1, "min": 22.278893564261644, "max": 22.278893564261644}}}
# #metrics {"StartTime": 1656179252.447506, "EndTime": 1656179252.4475474, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 19.996341480928308, "count": 1, "min": 19.996341480928308, "max": 19.996341480928308}}}
# #metrics {"StartTime": 1656179252.4478242, "EndTime": 1656179252.4478443, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 21.300947600719976, "count": 1, "min": 21.300947600719976, "max": 21.300947600719976}}}
# #metrics {"StartTime": 1656179252.448144, "EndTime": 1656179252.44818, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 20.410290287990197, "count": 1, "min": 20.410290287990197, "max": 20.410290287990197}}}
# #metrics {"StartTime": 1656179252.4484632, "EndTime": 1656179252.4485006, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 16.578096875957414, "count": 1, "min": 16.578096875957414, "max": 16.578096875957414}}}
# #metrics {"StartTime": 1656179252.448794, "EndTime": 1656179252.4488328, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 16.534207811542586, "count": 1, "min": 16.534207811542586, "max": 16.534207811542586}}}
# #metrics {"StartTime": 1656179252.4491272, "EndTime": 1656179252.4491751, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 16.100252637676164, "count": 1, "min": 16.100252637676164, "max": 16.100252637676164}}}
# #metrics {"StartTime": 1656179252.4495118, "EndTime": 1656179252.4495473, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 52.55871342677696, "count": 1, "min": 52.55871342677696, "max": 52.55871342677696}}}
# #metrics {"StartTime": 1656179252.4498405, "EndTime": 1656179252.4498782, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 49.046001359528184, "count": 1, "min": 49.046001359528184, "max": 49.046001359528184}}}
# #metrics {"StartTime": 1656179252.4501767, "EndTime": 1656179252.450234, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 51.05613558900122, "count": 1, "min": 51.05613558900122, "max": 51.05613558900122}}}
# #metrics {"StartTime": 1656179252.4505286, "EndTime": 1656179252.4505649, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 48.817267922794116, "count": 1, "min": 48.817267922794116, "max": 48.817267922794116}}}
# #metrics {"StartTime": 1656179252.450878, "EndTime": 1656179252.450915, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 56.97992302389706, "count": 1, "min": 56.97992302389706, "max": 56.97992302389706}}}
# #metrics {"StartTime": 1656179252.4512036, "EndTime": 1656179252.4512403, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 56.42762427236519, "count": 1, "min": 56.42762427236519, "max": 56.42762427236519}}}
# #metrics {"StartTime": 1656179252.451524, "EndTime": 1656179252.4515634, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 60.14939730775122, "count": 1, "min": 60.14939730775122, "max": 60.14939730775122}}}
# ...
# #metrics {"StartTime": 1656179256.0524244, "EndTime": 1656179256.0524333, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 0.9791723106588636, "count": 1, "min": 0.9791723106588636, "max": 0.9791723106588636}}}
# #metrics {"StartTime": 1656179256.0524654, "EndTime": 1656179256.0524738, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 0.9751555281026023, "count": 1, "min": 0.9751555281026023, "max": 0.9751555281026023}}}
# [06/25/2022 17:47:36 INFO 140021956077376] #quality_metric: host=algo-1, epoch=7, train mse_objective <loss>=0.30957955388086184
# #metrics {"StartTime": 1656179256.1431897, "EndTime": 1656179256.1432672, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 15.867431640625, "count": 1, "min": 15.867431640625, "max": 15.867431640625}}}
# #metrics {"StartTime": 1656179256.1485944, "EndTime": 1656179256.1486423, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 16.063629150390625, "count": 1, "min": 16.063629150390625, "max": 16.063629150390625}}}
# #metrics {"StartTime": 1656179256.1490133, "EndTime": 1656179256.149066, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 15.629229377297793, "count": 1, "min": 15.629229377297793, "max": 15.629229377297793}}}
# #metrics {"StartTime": 1656179256.1494334, "EndTime": 1656179256.1494846, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 15.44520538928462, "count": 1, "min": 15.44520538928462, "max": 15.44520538928462}}}
# #metrics {"StartTime": 1656179256.1498141, "EndTime": 1656179256.1498659, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 15.47210573682598, "count": 1, "min": 15.47210573682598, "max": 15.47210573682598}}}
# #metrics {"StartTime": 1656179256.1501803, "EndTime": 1656179256.1502233, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 15.509259691425399, "count": 1, "min": 15.509259691425399, "max": 15.509259691425399}}}
# #metrics {"StartTime": 1656179256.1513453, "EndTime": 1656179256.1513686, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 15.429426305434284, "count": 1, "min": 15.429426305434284, "max": 15.429426305434284}}}
# #metrics {"StartTime": 1656179256.1517167, "EndTime": 1656179256.15176, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 15.567351098154106, "count": 1, "min": 15.567351098154106, "max": 15.567351098154106}}}
# #metrics {"StartTime": 1656179256.152065, "EndTime": 1656179256.152107, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 15.71133841720282, "count": 1, "min": 15.71133841720282, "max": 15.71133841720282}}}
# #metrics {"StartTime": 1656179256.1524127, "EndTime": 1656179256.1524541, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 15.627433627259498, "count": 1, "min": 15.627433627259498, "max": 15.627433627259498}}}
# #metrics {"StartTime": 1656179256.1527808, "EndTime": 1656179256.1528187, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 15.36659091126685, "count": 1, "min": 15.36659091126685, "max": 15.36659091126685}}}
# #metrics {"StartTime": 1656179256.153133, "EndTime": 1656179256.15318, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 15.402905632467832, "count": 1, "min": 15.402905632467832, "max": 15.402905632467832}}}
# #metrics {"StartTime": 1656179256.1534884, "EndTime": 1656179256.1535323, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 15.387958003025428, "count": 1, "min": 15.387958003025428, "max": 15.387958003025428}}}
# #metrics {"StartTime": 1656179256.1538355, "EndTime": 1656179256.153878, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 15.458504471124387, "count": 1, "min": 15.458504471124387, "max": 15.458504471124387}}}
# #metrics {"StartTime": 1656179256.1542034, "EndTime": 1656179256.1542482, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 15.395527858360142, "count": 1, "min": 15.395527858360142, "max": 15.395527858360142}}}
# #metrics {"StartTime": 1656179256.1546397, "EndTime": 1656179256.15468, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 15.474777820063572, "count": 1, "min": 15.474777820063572, "max": 15.474777820063572}}}
# #metrics {"StartTime": 1656179256.1549933, "EndTime": 1656179256.1550379, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 16.714871874042586, "count": 1, "min": 16.714871874042586, "max": 16.714871874042586}}}
# #metrics {"StartTime": 1656179256.1553478, "EndTime": 1656179256.1553884, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 16.662089029947918, "count": 1, "min": 16.662089029947918, "max": 16.662089029947918}}}
# #metrics {"StartTime": 1656179256.155692, "EndTime": 1656179256.1557355, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 16.62997616038603, "count": 1, "min": 16.62997616038603, "max": 16.62997616038603}}}
# #metrics {"StartTime": 1656179256.156064, "EndTime": 1656179256.1561038, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 16.624024035883885, "count": 1, "min": 16.624024035883885, "max": 16.624024035883885}}}
# #metrics {"StartTime": 1656179256.1564093, "EndTime": 1656179256.1564522, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 15.440835391773897, "count": 1, "min": 15.440835391773897, "max": 15.440835391773897}}}
# #metrics {"StartTime": 1656179256.1567562, "EndTime": 1656179256.156799, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 15.360497568167892, "count": 1, "min": 15.360497568167892, "max": 15.360497568167892}}}
# #metrics {"StartTime": 1656179256.1571002, "EndTime": 1656179256.1571414, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 15.391742182712928, "count": 1, "min": 15.391742182712928, "max": 15.391742182712928}}}
# #metrics {"StartTime": 1656179256.1574628, "EndTime": 1656179256.1575153, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 15.367945053998161, "count": 1, "min": 15.367945053998161, "max": 15.367945053998161}}}
# #metrics {"StartTime": 1656179256.1578293, "EndTime": 1656179256.157871, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 51.417777267156865, "count": 1, "min": 51.417777267156865, "max": 51.417777267156865}}}
# #metrics {"StartTime": 1656179256.158226, "EndTime": 1656179256.1582656, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 51.3711607689951, "count": 1, "min": 51.3711607689951, "max": 51.3711607689951}}}
# #metrics {"StartTime": 1656179256.1585903, "EndTime": 1656179256.1586313, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 51.269581514246326, "count": 1, "min": 51.269581514246326, "max": 51.269581514246326}}}
# #metrics {"StartTime": 1656179256.1589315, "EndTime": 1656179256.158975, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 51.212871476715684, "count": 1, "min": 51.212871476715684, "max": 51.212871476715684}}}
# #metrics {"StartTime": 1656179256.1592903, "EndTime": 1656179256.1593392, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 55.34401089537378, "count": 1, "min": 55.34401089537378, "max": 55.34401089537378}}}
# #metrics {"StartTime": 1656179256.159681, "EndTime": 1656179256.159738, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 53.71058565027573, "count": 1, "min": 53.71058565027573, "max": 53.71058565027573}}}
# #metrics {"StartTime": 1656179256.160099, "EndTime": 1656179256.1601424, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 55.47886747472427, "count": 1, "min": 55.47886747472427, "max": 55.47886747472427}}}
# #metrics {"StartTime": 1656179256.160447, "EndTime": 1656179256.1604886, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 53.946236404718135, "count": 1, "min": 53.946236404718135, "max": 53.946236404718135}}}
# [06/25/2022 17:47:36 INFO 140021956077376] #quality_metric: host=algo-1, epoch=7, validation mse_objective <loss>=15.867431640625
# [06/25/2022 17:47:36 INFO 140021956077376] #early_stopping_criteria_metric: host=algo-1, epoch=7, criteria=mse_objective, value=15.360497568167892
# [06/25/2022 17:47:36 INFO 140021956077376] Saving model for epoch: 7
# [06/25/2022 17:47:36 INFO 140021956077376] Saved checkpoint to "/tmp/tmp4c_xox3g/mx-mod-0000.params"
# [06/25/2022 17:47:36 INFO 140021956077376] Early stop condition met. Stopping training.
# [06/25/2022 17:47:36 INFO 140021956077376] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1656179255.4618778, "EndTime": 1656179256.1741416, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 7, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 4127.0, "count": 1, "min": 4127, "max": 4127}, "Total Batches Seen": {"sum": 136.0, "count": 1, "min": 136, "max": 136}, "Max Records Seen Between Resets": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Max Batches Seen Between Resets": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Reset Count": {"sum": 10.0, "count": 1, "min": 10, "max": 10}, "Number of Records Since Last Reset": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Number of Batches Since Last Reset": {"sum": 15.0, "count": 1, "min": 15, "max": 15}}}
# [06/25/2022 17:47:36 INFO 140021956077376] #throughput_metric: host=algo-1, train throughput=638.3956014989051 records/second
# [06/25/2022 17:47:36 WARNING 140021956077376] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [06/25/2022 17:47:36 WARNING 140021956077376] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [06/25/2022 17:47:36 INFO 140021956077376] #early_stopping_criteria_metric: host=algo-1, epoch=7, criteria=mse_objective, value=15.360497568167892
# [06/25/2022 17:47:36 INFO 140021956077376] #validation_score (algo-1) : ('mse_objective', 15.13801185757506)
# [06/25/2022 17:47:36 INFO 140021956077376] #validation_score (algo-1) : ('mse', 15.13801185757506)
# [06/25/2022 17:47:36 INFO 140021956077376] #validation_score (algo-1) : ('absolute_loss', 2.9923543743058745)
# [06/25/2022 17:47:36 INFO 140021956077376] #validation_score (algo-1) : ('rmse', 3.8907598046622027)
# [06/25/2022 17:47:36 INFO 140021956077376] #validation_score (algo-1) : ('r2', 0.7186086298510037)
# [06/25/2022 17:47:36 INFO 140021956077376] #validation_score (algo-1) : ('mae', 2.9923543743058745)
# [06/25/2022 17:47:36 INFO 140021956077376] #quality_metric: host=algo-1, validation mse_objective <loss>=15.13801185757506
# [06/25/2022 17:47:36 INFO 140021956077376] #quality_metric: host=algo-1, validation mse <loss>=15.13801185757506
# [06/25/2022 17:47:36 INFO 140021956077376] #quality_metric: host=algo-1, validation absolute_loss <loss>=2.9923543743058745
# [06/25/2022 17:47:36 INFO 140021956077376] #quality_metric: host=algo-1, validation rmse <loss>=3.8907598046622027
# [06/25/2022 17:47:36 INFO 140021956077376] #quality_metric: host=algo-1, validation r2 <loss>=0.7186086298510037
# [06/25/2022 17:47:36 INFO 140021956077376] #quality_metric: host=algo-1, validation mae <loss>=2.9923543743058745
# [06/25/2022 17:47:36 INFO 140021956077376] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 1, "l1": 0.0, "lr_scheduler_step": 100, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 0.0001}
# [06/25/2022 17:47:36 INFO 140021956077376] Saved checkpoint to "/tmp/tmpli6n_nal/mx-mod-0000.params"
# [06/25/2022 17:47:36 INFO 140021956077376] Test data is not provided.
# #metrics {"StartTime": 1656179250.941008, "EndTime": 1656179256.3152113, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 363.01398277282715, "count": 1, "min": 363.01398277282715, "max": 363.01398277282715}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 10.522127151489258, "count": 9, "min": 0.3285408020019531, "max": 3.213644027709961}, "update.time": {"sum": 4813.066482543945, "count": 8, "min": 441.73431396484375, "max": 836.1060619354248}, "finalize.time": {"sum": 130.45239448547363, "count": 1, "min": 130.45239448547363, "max": 130.45239448547363}, "setuptime": {"sum": 58.52508544921875, "count": 1, "min": 58.52508544921875, "max": 58.52508544921875}, "totaltime": {"sum": 5749.050855636597, "count": 1, "min": 5749.050855636597, "max": 5749.050855636597}}}
#
# 2022-06-25 17:47:53 Uploading - Uploading generated training model
# 2022-06-25 17:47:53 Completed - Training job completed
# Training seconds: 149
# Billable seconds: 149

# %%
# %%bash -s "$ll_estimator.output_path"
# aws s3 ls --recursive $1
# Out:
# 2022-06-25 17:47:46        919 boston-housing/output/linear-learner-2022-06-25-17-44-05-318/output/model.tar.gz
# 2022-06-25 17:47:48          0 boston-housing/output/linear-learner-2022-06-25-17-44-05-318/profiler-output/framework/training_job_end.ts
# 2022-06-25 17:47:01      81804 boston-housing/output/linear-learner-2022-06-25-17-44-05-318/profiler-output/system/incremental/2022062517/1656179100.algo-1.json
# 2022-06-25 17:47:01     183863 boston-housing/output/linear-learner-2022-06-25-17-44-05-318/profiler-output/system/incremental/2022062517/1656179160.algo-1.json
# 2022-06-25 17:47:44     131398 boston-housing/output/linear-learner-2022-06-25-17-44-05-318/profiler-output/system/incremental/2022062517/1656179220.algo-1.json
# 2022-06-25 17:47:48          0 boston-housing/output/linear-learner-2022-06-25-17-44-05-318/profiler-output/system/training_job_end.ts
# 2022-06-25 17:48:34     329721 boston-housing/output/linear-learner-2022-06-25-17-44-05-318/rule-output/ProfilerReport-1656179045/profiler-output/profiler-report.html
# 2022-06-25 17:48:33     171093 boston-housing/output/linear-learner-2022-06-25-17-44-05-318/rule-output/ProfilerReport-1656179045/profiler-output/profiler-report.ipynb
# 2022-06-25 17:48:30        191 boston-housing/output/linear-learner-2022-06-25-17-44-05-318/rule-output/ProfilerReport-1656179045/profiler-output/profiler-reports/BatchSize.json
# 2022-06-25 17:48:30        199 boston-housing/output/linear-learner-2022-06-25-17-44-05-318/rule-output/ProfilerReport-1656179045/profiler-output/profiler-reports/CPUBottleneck.json
# 2022-06-25 17:48:30        126 boston-housing/output/linear-learner-2022-06-25-17-44-05-318/rule-output/ProfilerReport-1656179045/profiler-output/profiler-reports/Dataloader.json
# 2022-06-25 17:48:30        127 boston-housing/output/linear-learner-2022-06-25-17-44-05-318/rule-output/ProfilerReport-1656179045/profiler-output/profiler-reports/GPUMemoryIncrease.json
# 2022-06-25 17:48:30        198 boston-housing/output/linear-learner-2022-06-25-17-44-05-318/rule-output/ProfilerReport-1656179045/profiler-output/profiler-reports/IOBottleneck.json
# 2022-06-25 17:48:30        119 boston-housing/output/linear-learner-2022-06-25-17-44-05-318/rule-output/ProfilerReport-1656179045/profiler-output/profiler-reports/LoadBalancing.json
# 2022-06-25 17:48:30        151 boston-housing/output/linear-learner-2022-06-25-17-44-05-318/rule-output/ProfilerReport-1656179045/profiler-output/profiler-reports/LowGPUUtilization.json
# 2022-06-25 17:48:30        178 boston-housing/output/linear-learner-2022-06-25-17-44-05-318/rule-output/ProfilerReport-1656179045/profiler-output/profiler-reports/MaxInitializationTime.json
# 2022-06-25 17:48:30        133 boston-housing/output/linear-learner-2022-06-25-17-44-05-318/rule-output/ProfilerReport-1656179045/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# 2022-06-25 17:48:30        466 boston-housing/output/linear-learner-2022-06-25-17-44-05-318/rule-output/ProfilerReport-1656179045/profiler-output/profiler-reports/OverallSystemUsage.json
# 2022-06-25 17:48:30        156 boston-housing/output/linear-learner-2022-06-25-17-44-05-318/rule-output/ProfilerReport-1656179045/profiler-output/profiler-reports/StepOutlier.json

# %%
from time import strftime, gmtime
timestamp = strftime('%d-%H-%M-%S', gmtime())

endpoint_name = 'linear-learner-demo-'+timestamp
print(endpoint_name)
# Out:
# linear-learner-demo-25-17-49-07

# %%
ll_predictor = ll_estimator.deploy(endpoint_name=endpoint_name, 
                        initial_instance_count=1, 
                        instance_type='ml.t2.medium')
# Out:
# -------------!

# %%
test_sample = '0.00632,18.00,2.310,0,0.5380,6.5750,65.20,4.0900,1,296.0,15.30,4.98'

# %%
#ll_predictor.content_type = 'text/csv'
ll_predictor.serializer = sagemaker.serializers.CSVSerializer()
ll_predictor.deserializer = sagemaker.deserializers.CSVDeserializer()

response = ll_predictor.predict(test_sample)
print(response)
# Out:
# [['28.51776885986328']]

# %%
test_samples = ['0.00632,18.00,2.310,0,0.5380,6.5750,65.20,4.0900,1,296.0,15.30,4.98',
                '0.02731,0.00,7.070,0,0.4690,6.4210,78.90,4.9671,2,242.0,17.80,9.14']

response = ll_predictor.predict(test_samples)
print(response)
print(ll_predictor.endpoint_name)
# Out:
# [['28.51776885986328'], ['24.39436149597168']]
# linear-learner-demo-25-17-49-07

# %%
runtime = boto3.Session().client(service_name='runtime.sagemaker') 

response = runtime.invoke_endpoint(EndpointName=endpoint_name, 
                                  ContentType='text/csv', 
                                  Body=test_sample)

print(response['Body'].read())
# Out:
# b'{"predictions": [{"score": 28.51776885986328}]}'

# %%
ll_predictor.delete_endpoint()
